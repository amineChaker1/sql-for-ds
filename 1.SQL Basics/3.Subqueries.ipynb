# %% [markdown]
# ### Definitions

# %% [markdown]
# ![40.png](attachment:bd786266-b69c-4690-9539-6a7e6bb4ecd5.png)

# %% [markdown]
# ![41.png](attachment:1c220faf-11e8-4598-8f4a-9a9e8800288a.png)

# %% [markdown]
# ![42.png](attachment:d6d1a010-db9a-4fa2-bf2c-95b6312df9af.png)

# %% [markdown]
# ![44.png](attachment:106afc1c-a880-408a-a159-8a98babc9cff.png)

# %% [markdown]
# ![45.png](attachment:4179e086-8559-4487-b178-1655e2ec8128.png)

# %% [markdown]
# ![43.png](attachment:360b46f7-99b4-4265-a4c7-e92714db7f88.png)

# %% [markdown]
# ### Joins
